# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='white', color_codes=True)

# %% [markdown]
# ## Describing Data

# %%
d = pd.read_csv('HR_comma_sep.csv')
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# sales                    14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
d.describe()
# data set is clean
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
# there are some confusions about col names
# change time_spend_company -> time_spend_company_yrs
# change sales -> department
# notice that here we can't use d = d.rename...
d.rename(index=str, columns={'time_spend_company':'time_spend_company_yrs', 'sales':'department'}, inplace=True)
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company_yrs  Work_accident  left  promotion_last_5years  \
# 0                       3              0     1                      0
# 1                       6              0     1                      0
# 2                       4              0     1                      0
# 3                       5              0     1                      0
# 4                       3              0     1                      0
#
#   department  salary
# 0      sales     low
# 1      sales  medium
# 2      sales  medium
# 3      sales     low
# 4      sales     low

# %%
# distribution of salary & department & distribution
print(d.salary.value_counts(), end='\n\n')
print(d.department.value_counts(), end='\n\n')
print(d.left.value_counts(), end='\n\n')
print(d.promotion_last_5years.value_counts())
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64
#
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64
#
# 0    11428
# 1     3571
# Name: left, dtype: int64
#
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %% [markdown]
# ## Research Questions

# %% [markdown]
# The initial question asked by the dataset provider is why their best and most experienced employees leaving permaturely（过早的）? To answer this question, I want to split this big question into several smaller ones.
#
# Taking a look at our data and some descriptive statistics, we can quickly calculate and see that over 95% of the employees didn't get a promotion over the last 5 years in the company while the average years they stayed in the company was less than 4 years. And 1/4 of the employees chose to leave. Whether they got a promotion or not could possibly lead to their choice of leaving.
#
# In this data set, the target column is 'left'. All other features seem pretty relevant to to target, and possibly to each other. However, we can pick a few most obvious ones to start with:
# - salary
# - promotion
# - satisfaction
# - department
# - average monthly hrs
#
# With these features, we can analyze which feature has the most significant impact on "left".

# %% [markdown]
# ## Exploratory Data Visualization

# %% [markdown]
# ### Heatmap

# %%
# 1st plot - sns.heatmap - determine important features
# annot=True labels values on each cube
# the 1st line makes the heatmap bigger
_, ax = plt.subplots(figsize =(11,9))
sns.heatmap(d.corr(), vmax=1, 
            annot=True, annot_kws = {'fontsize': 14}, 
            cbar_kws={ 'shrink' : 0.9 },
            square=True, 
            ax=ax)

# %% [markdown]
# From the above heatmap, we can see that 'average_monthly_hours' and 'number_project' has the largest coefficient level. Also, 'satisfaction_level' seems to have an impact on 'left'.

# %% [markdown]
# ### Other features

# %%
# 1st plot - FacetGrid plt.hist
# at first, we just lay everything out!
# doesn't work this way...
sns.FacetGrid(d, col='left')\
   .map(plt.hist, ['satisfaction_level', 'last_evaluation', 'number_project', 'average_monthly_hours', 'time_spend_company', 'Work_accident', 'promition_last_5years'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-634c3d9e458f> in <module>()
#       2 # at first, we just lay everything out!
#       3 # doesn't work this way...
# ----> 4 sns.FacetGrid(d, col='left')   .map(plt.hist, ['satisfaction_level', 'last_evaluation', 'number_project', 'average_monthly_hours', 'time_spend_company', 'Work_accident', 'promition_last_5years'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     715
#     716             # Get the actual data we are going to plot with
# --> 717             plot_data = data_ijk[list(args)]
#     718             if self._dropna:
#     719                 plot_data = plot_data.dropna()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2095             return self.take(indexer, axis=0, convert=False)
#    2096         else:
# -> 2097             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2098             return self.take(indexer, axis=1, convert=True)
#    2099
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1216                     # unique index
#    1217                     if labels.is_unique:
# -> 1218                         indexer = check = labels.get_indexer(objarr)
#    1219
#    1220                     # non-unique (dups)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2284                                  'backfill or nearest reindexing')
#    2285
# -> 2286             indexer = self._engine.get_indexer(target._values)
#    2287
#    2288         return _ensure_platform_int(indexer)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_indexer (pandas\index.c:6421)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.lookup (pandas\hashtable.c:14646)()
#
# TypeError: unhashable type: 'list'

# %%
# 1st plot revision - pandas.hist
# not bad, but we want to divide them by 'left'
d.hist(figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002446C749D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446C7AAAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446C817550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002446C86A2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446C8CEC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446C8CEC50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002446C993160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446C9E9390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446CA4EB00>]], dtype=object)

# %%
# 1st plot revision - 'left' == 0
# this works, but not efficient
d[d['left'] == 0].hist(figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002446CE67438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446CC1CF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446CC81CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002446CCD94A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446CD3FCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446CD3FCF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002446D094320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446D0EA668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002446D14ECF8>]], dtype=object)

# %%
# 1st plot revision - FacetGrid plt.hist - satisfaction & left
# it doesn't work with all features
sns.FacetGrid(d, col='left')\
   .map(plt.hist, 'satisfaction_level', bins=20)

# %%
# 1st plot revision - groupby!!!
# finally works!!!
# layout controls number of hist row*col
# figsize=(16,7) is perfect
# one flaw is that there's no label whether left=0 or left=1, we can only judge by the two lines below
d.groupby('left').hist(color='m', bins=20, layout=(2,4), figsize=(16,7))
# Out:
# left
# 0    [[Axes(0.125,0.551739;0.158163x0.328261), Axes...
# 1    [[Axes(0.125,0.551739;0.158163x0.328261), Axes...
# dtype: object

# %%
# some statistics about the above graph
# monthly hours
print('Monthly hours:')
print('stayed vs left:', round(d[d['left'] == 0].average_montly_hours.mean(),2), 'vs', round(d[d['left'] == 1].average_montly_hours.mean(),2))
# last evaluation
print('\nLast evaluation:')
print('stayed vs left:', round(d[d['left'] == 0].last_evaluation.mean(),2), 'vs', round(d[d['left'] == 1].last_evaluation.mean(),2))
# Number of projects
print('\nNumber of projects:')
print('stayed vs left:', round(d[d['left'] == 0].number_project.mean(),2), 'vs', round(d[d['left'] == 1].number_project.mean(),2))
print('stayed vs left - proportion of projects >= 6:', 
      round(d[(d['left'] == 0) & (d['number_project'] >= 6)].number_project.count() / d[(d['left'] == 0)].number_project.count() * 100,2), '%',
      'vs',
      round(d[(d['left'] == 1) & (d['number_project'] >= 6)].number_project.count() / d[(d['left'] == 1)].number_project.count() * 100,2), '%'
     )
# Satisfaction Level
print('\nSatisfaction level:')
print('stayed vs left:', round(d[d['left'] == 0].satisfaction_level.mean(),2), 'vs', round(d[d['left'] == 1].satisfaction_level.mean(),2))
# Time in company
print('\nTime in company:')
print('stayed vs left:', round(d[d['left'] == 0].time_spend_company_yrs.mean(),2), 'vs', round(d[d['left'] == 1].time_spend_company_yrs.mean(),2))
# Out:
# Monthly hours:
# stayed vs left: 199.06 vs 207.42
#
# Last evaluation:
# stayed vs left: 0.72 vs 0.72
#
# Number of projects:
# stayed vs left: 3.79 vs 3.86
# stayed vs left - proportion of projects >= 6: 4.54 % vs 25.51 %
#
# Satisfaction level:
# stayed vs left: 0.67 vs 0.44
#
# Time in company:
# stayed vs left: 3.38 vs 3.88

# %% [markdown]
# The above grouped charts and statistics indicate that:
# - monthly hours: people who stayed worked less than who left, but more centered; left people either worked little or a lot;
# - last evaluation: averages are equal, both 0.72, but again, left people either had very bad or great evaluations;
# - number of projects: averages are similar, but a much larger proportion of left people had 6 projects or more;
# - satisfaction level: people who stayed were more satisfied than who left;
# - time in company: people who stayed spent fewer years than who left.

# %% [markdown]
# There are still two missing parts - "salary" and "department", which are categorical parts. We may convert these two features to numerical values later. For now, let's see if employees' salary and department plays a role.

# %%
# let's explore if salary plays a part
# employee's with low salary have higher chance of leaving. 
d[['salary', 'left']].groupby(['salary'], as_index=False).mean().sort_values(by='left', ascending=False)
# Out:
#    salary      left
# 1     low  0.296884
# 2  medium  0.204313
# 0    high  0.066289

# %%
# what about department
# it turns out that employees of some departments have higher chance of leaving. 
d[['department', 'left']].groupby(['department'], as_index=False).mean().sort_values(by='left', ascending=False)
# Out:
#     department      left
# 3           hr  0.290934
# 2   accounting  0.265971
# 9    technical  0.256250
# 8      support  0.248991
# 7        sales  0.244928
# 5    marketing  0.236597
# 0           IT  0.222494
# 6  product_mng  0.219512
# 1        RandD  0.153748
# 4   management  0.144444

# %%
# 2nd plot - left & salary & satisfaction level
sns.FacetGrid(d, col='left', row='salary')\
   .map(plt.hist, 'satisfaction_level', bins=20)

# %%
# 3rd plot - boxplot - left & number_project & satisfaction_level
# we can see that left people who had 6 or more projects have very low satisfaction levels
sns.boxplot(data=d[d['left'] == 1], orient='h', x='satisfaction_level', y='number_project', palette='Set2', linewidth=1)

# %%
# 4th plot - pointplot - left & number_project & salary & department
# this gives a lot information, but too squeezed to see the truth
# at a glance, we can tell that for employees of all departments with low and medium salaries, the relationship between their number of projects and leavings is positive when they have 3 or more projects. However, this relationship is more diverse with high salary people among departments.
sns.FacetGrid(d, row='salary', size=5, aspect=2)\
   .map(sns.pointplot, 'number_project', 'left', 'department', palette='deep')\
   .add_legend()

# %%
# 4th plot revision - left & number_project & department & salary
# this one is more obvious to see. 
# most departments follow a "U" shape, with different patterns. 
# didn't figure out how to change legend order inside the block
sns.FacetGrid(d, row='department', size=2, aspect=3)\
   .map(sns.pointplot, 'number_project', 'left', 'salary', palette='deep')\
   .add_legend(prop={'size': 20}) # controls the legend size

# %%
# 5th plot - pairplot
# it doesn't give us anything
sns.pairplot(d, hue='left')

# %%
# 6th plot - scatterplot - left & average_monthly_hours & number_project
# this plot proves one point we made previously that average_monthly_hours and number_project is positively related, especially for left people having done 4 or more projects
d[d['left'] == 1].plot(kind='scatter', x='number_project', y='average_montly_hours')

# %% [markdown]
# ## Conclusions

# %% [markdown]
# From some statistics and visualizations we made, we have more confidence to identify some of the most important features. I think the most import two features are:
# - satisfaction level
# - number of projects
#
# Other features may have similar levels of importance. I'm not sure how to test them yet, maybe in some machine learning algorithms. And our target feature is:
# - left
#
# With the explorations we did before, we can handle the next parts to machine learning, which I will do in another repository.
